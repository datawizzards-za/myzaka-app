# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'myzaka.settings')
import django
django.setup()

import urllib3
import requests
import pandas as pd

# %%
from app import models

from sqlalchemy import create_engine
engine = create_engine('sqlite:///myzakadb.sqlite3')

# %%
engine.table_names()
# Out:
# ['app_audits',
#  'app_balancesheet',
#  'app_capital',
#  'app_cashflow',
#  'app_forecast',
#  'app_incomeexpense',
#  'app_maintenance',
#  'app_municipalities',
#  'app_municipalities_audits',
#  'app_municipalities_balance_sheets',
#  'app_municipalities_capital',
#  'app_municipalities_cash_flows',
#  'app_municipalities_forecasts',
#  'app_municipalities_income_expense',
#  'app_municipalities_maintenance',
#  'app_municipalities_officials',
#  'app_municipalities_wasteful',
#  'app_officials',
#  'app_wastefulexpenditure',
#  'auth_group',
#  'auth_group_permissions',
#  'auth_permission',
#  'auth_user',
#  'auth_user_groups',
#  'auth_user_user_permissions',
#  'django_admin_log',
#  'django_content_type',
#  'django_migrations',
#  'django_session',
#  'sqlite_sequence']

# %% [markdown]
# ### Generate Officials data

# %%
try:
    officials = pd.DataFrame(requests.get('https://municipaldata.treasury.gov.za/api/cubes/officials/facts',
                                          allow_redirects=True).json()['data'])

    officials.fillna('not availiable', inplace=True)
    for col in officials.columns:
        officials[col] = officials[col].apply(lambda x: str(x).lower())

    officials = officials[['contact_details.title',  'role.role', 'contact_details.name',  'contact_details.email_address', 
               'contact_details.fax_number', 'contact_details.phone_number', 'municipality.demarcation_code']]

    officials.rename(columns={'contact_details.title':'title',  'role.role':'role', 'contact_details.name':'name',  
                                                            'contact_details.email_address':'email_address', 'contact_details.fax_number':'fax_number', 
                                                             'contact_details.phone_number':'phone_number', 'municipality.demarcation_code':'demarcation_code'}, inplace=True)
    officials.drop_duplicates(inplace=True)

    models.Officials.objects.all().delete()
    officials.to_sql('app_officials', engine, if_exists='append', index=False)
    models.Officials.objects.count()
except Exception as ex:
    print("ERROR:", ex)

# %% [markdown]
# ### Generate BalanceSheet data

# %%
try:
    balance_sheet = pd.DataFrame(requests.get('https://municipaldata.treasury.gov.za/api/cubes/bsheet/facts',
                                          allow_redirects=True).json()['data'])

    balance_sheet.amount = balance_sheet.amount.transform(lambda x: x.fillna('0'))

    for col in balance_sheet.columns:
        balance_sheet[col] = balance_sheet[col].apply(lambda x: str(x).lower())

    balance_sheet = balance_sheet[['demarcation.label', 'demarcation.code', 'financial_year_end.year', 'amount', 'item.label', 'amount_type.label']]
    balance_sheet.rename(columns={'demarcation.code':'demarcation_code', 'demarcation.label':'demarcation_label', 
                              'financial_year_end.year':'financial_year_end', 'item.label':'item_label', 
                              'amount':'amount', 'amount_type.label':'amount_type'}, inplace=True)
    balance_sheet.amount = balance_sheet.amount.transform(lambda x: float(x))
    balance_sheet.financial_year_end = balance_sheet.financial_year_end.transform(lambda x: int(x))

    balance_sheet = balance_sheet.sort_values(by=['financial_year_end', 'amount'], ascending=False)
    balance_sheet.drop_duplicates(inplace=True, subset=['demarcation_code', 
                                          'financial_year_end','item_label', 'amount_type'])

    balance_sheet.fillna('not availiable', inplace=True)
    models.BalanceSheet.objects.all().delete()
    balance_sheet.to_sql('app_balancesheet', engine, if_exists='append', index=False)
    models.BalanceSheet.objects.count()
    
except Exception as ex:
    print("ERROR:", ex)

# %% [markdown]
# ### Generate Cash Flow data

# %%
try:
    cash_flows = pd.DataFrame(requests.get('https://municipaldata.treasury.gov.za/api/cubes/cflow/facts',
                                          allow_redirects=True).json()['data'])

    cash_flows.amount = cash_flows.amount.transform(lambda x: x.fillna('0'))

    for col in cash_flows.columns:
        cash_flows[col] = cash_flows[col].apply(lambda x: str(x).lower())

    cash_flows_df = cash_flows[['amount_type.label', 'demarcation.code', 'financial_year_end.year', 'amount', 'item.label']]
    cash_flows_df.rename(columns={'demarcation.code':'demarcation_code', 'amount_type.label':'amount_type', 
                              'financial_year_end.year':'financial_year_end', 'item.label':'item_label'}, inplace=True)
    cash_flows_df.amount = cash_flows_df.amount.transform(lambda x: float(x))
    cash_flows_df.financial_year_end = cash_flows_df.financial_year_end.transform(lambda x: int(x))

    cash_flows_df = cash_flows_df.sort_values(by=['financial_year_end', 'amount'], ascending=False)
    cash_flows_df.drop_duplicates(inplace=True, subset=['demarcation_code', 'amount_type',
                                                       'financial_year_end', 'item_label'])

    cash_flows_df.fillna('not availiable', inplace=True)
    models.CashFlow.objects.all().delete()
    cash_flows_df.to_sql('app_cashflow', engine, if_exists='append', index=False)
    models.CashFlow.objects.count()
    
except Exception as ex:
    print("ERROR:", ex)
# Out:
# /home/doctor/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# /home/doctor/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# ### Generate Maintenance data

# %%
try:
    repairs = pd.DataFrame(requests.get('https://municipaldata.treasury.gov.za/api/cubes/repmaint/facts',
                                          allow_redirects=True).json()['data'])

    repairs.amount = repairs.amount.transform(lambda x: x.fillna('0'))
    for col in repairs.columns:
        repairs[col] = repairs[col].apply(lambda x: str(x).lower())

    repairs_df = repairs[['amount_type.label', 'demarcation.code', 'financial_year_end.year', 'amount', 'item.label']]

    repairs_df.rename(columns={'demarcation.code':'demarcation_code', 'amount_type.label':'amount_type', 
                              'financial_year_end.year':'financial_year_end', 'item.label':'item_label'}, inplace=True)
    repairs_df.amount = repairs_df.amount.transform(lambda x: float(x))
    repairs_df.financial_year_end = repairs_df.financial_year_end.transform(lambda x: int(x))

    repairs_df = repairs_df.sort_values(by=['financial_year_end', 'amount'], ascending=False)
    repairs_df.drop_duplicates(inplace=True, subset=['demarcation_code', 'amount_type',
                                                       'financial_year_end', 'item_label'])

    repairs_df.fillna('not availiable', inplace=True)
    models.Maintenance.objects.all().delete()
    repairs_df.to_sql('app_maintenance', engine, if_exists='append', index=False)
    models.Maintenance.objects.count()
    
except Exception as ex:
    print("ERROR:", ex)
# Out:
# /home/doctor/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# /home/doctor/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#repairs_df[(repairs_df['demarcation_code']=='buf') & (repairs_df['financial_year_end'] == '2012') & (repairs_df['item_label']=='contracted services')]

# %%
#repairs_df.groupby(['demarcation_code', 'financial_year_end', 'item_label']).count()

# %% [markdown]
# ### Generate Audits data

# %%
try:
    audits = pd.DataFrame(requests.get('https://municipaldata.treasury.gov.za/api/cubes/audit_opinions/facts',
                                          allow_redirects=True).json()['data'])

    audits.fillna('not availiable', inplace=True)
    for col in audits.columns:
        audits[col] = audits[col].apply(lambda x: str(x).lower())

    audits_df = audits[['demarcation.code', 'demarcation.label', 'financial_year_end.year', 'opinion.label', 'opinion.report_url']]
    audits_df.rename(columns={'demarcation.code':'demarcation_code', 'demarcation.label':'demarcation_label', 
                              'financial_year_end.year':'financial_year_end', 'opinion.label':'opinion', 
                              'opinion.report_url':'opinion_report_url'}, inplace=True)

    audits_df.financial_year_end = audits_df.financial_year_end.transform(lambda x: int(x))

    audits_df = audits_df.sort_values(by=['financial_year_end'], ascending=False)
    audits_df.drop_duplicates(inplace=True) 

    models.Audits.objects.all().delete()
    audits_df.to_sql('app_audits', engine, if_exists='append', index=False)
    print("Object Count:", models.Audits.objects.count())
except Exception as ex:
    print("ERROR:", ex)
# Out:
# Object Count: 1632
# /home/doctor/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# /home/doctor/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# ### Generate WastefulExpese data

# %%
try:
    wasteful = pd.DataFrame(requests.get('https://municipaldata.treasury.gov.za/api/cubes/uifwexp/facts',
                                          allow_redirects=True).json()['data'])

    wasteful.amount = wasteful.amount.transform(lambda x: x.fillna(0))

    for col in wasteful.columns:
        wasteful[col] = wasteful[col].apply(lambda x: str(x).lower())

    wasteful.drop(['item.code'], axis=1, inplace=True)
    wasteful.rename(columns={'demarcation.code':'demarcation_code', 'demarcation.label':'demarcation_label', 
                            'financial_year_end.year':'financial_year_end', 'item.label':'item_label'}, inplace=True)
    wasteful.amount = wasteful.amount.transform(lambda x: float(x))
    wasteful.financial_year_end = wasteful.financial_year_end.transform(lambda x: int(x))

    wasteful = wasteful.sort_values(by=['financial_year_end', 'amount'], ascending=False)
    wasteful.drop_duplicates(inplace=True)

    wasteful.fillna('not availiable', inplace=True)
    models.WastefulExpenditure.objects.all().delete()
    wasteful.to_sql('app_wastefulexpenditure', engine, if_exists='append', index=False)
    print("Object Count:", models.WastefulExpenditure.objects.count())
    
except Exception as ex:
    print("ERROR:", ex)
# Out:
# Object Count: 3333

# %% [markdown]
# ### Generate Capital Data

# %%
try:
    munis = pd.DataFrame(list(models.Officials.objects.all().values()))
    muni_codes = [str(x).upper() for x in pd.unique(munis.demarcation_code)]
    models.Capital.objects.all().delete()
    count = 1
    for code in muni_codes:
        print("processing {0} of {1}, {2} remaining...".format(count, len(muni_codes), len(muni_codes) - count))
        capital = pd.DataFrame(requests.get('https://municipaldata.treasury.gov.za/api/cubes/capital/aggregate?drilldown=demarcation.code|demarcation.label|item.label|financial_year_end.year|amount_type.label&cut=demarcation.code%3A%22' + code + '%22&aggregates=new_assets.sum|renewal_of_existing.sum|total_assets.sum',
                                          allow_redirects=True).json()['cells'])

        capital = capital[['amount_type.label', 'financial_year_end.year', 'item.label', 
                           'demarcation.code', 'demarcation.label', 'renewal_of_existing.sum', 
                           'total_assets.sum', 'new_assets.sum']]
        capital.rename(columns={'amount_type.label':'amount_type', 
                                'new_assets.sum':'sum_new_assets',
                                'financial_year_end.year':'financial_year_end', 
                                'renewal_of_existing.sum':'sum_renewed_assets', 
                                'item.label':'item_label', 
                                'total_assets.sum':'sum_total_assets',
                                'demarcation.code':'demarcation_code', 
                                'demarcation.label':'demarcation_label'}, inplace=True)

        capital.sum_new_assets = capital.sum_new_assets.transform(lambda x: x.fillna(0))
        capital.sum_renewed_assets = capital.sum_renewed_assets.transform(lambda x: x.fillna(0))
        capital.sum_total_assets = capital.sum_total_assets.transform(lambda x: x.fillna(0))

        for col in capital.columns:
            capital[col] = capital[col].apply(lambda x: str(x).lower())

        capital.sum_new_assets = capital.sum_new_assets.transform(lambda x: float(x))
        capital.sum_renewed_assets = capital.sum_renewed_assets.transform(lambda x: float(x))
        capital.sum_total_assets = capital.sum_total_assets.transform(lambda x: float(x))
        capital.financial_year_end = capital.financial_year_end.transform(lambda x: int(x))

        capital = capital.sort_values(by=['financial_year_end', 'sum_total_assets', 
                                          'sum_renewed_assets', 'sum_new_assets'], ascending=False)
        capital.drop_duplicates(inplace=True)

        capital.fillna('not availiable', inplace=True)
        models.Capital.objects.all().delete()
        capital.to_sql('app_capital', engine, if_exists='append', index=False)
        models.Capital.objects.count()
        count += 1
        
except Exception as ex:
    print("ERROR:", ex)
# Out:
# processing 1 of 292, 291 remaining...
# processing 2 of 292, 290 remaining...
# processing 3 of 292, 289 remaining...
# processing 4 of 292, 288 remaining...
# processing 5 of 292, 287 remaining...
# processing 6 of 292, 286 remaining...
# processing 7 of 292, 285 remaining...
# processing 8 of 292, 284 remaining...
# processing 9 of 292, 283 remaining...
# processing 10 of 292, 282 remaining...
# processing 11 of 292, 281 remaining...
# processing 12 of 292, 280 remaining...
# processing 13 of 292, 279 remaining...
# processing 14 of 292, 278 remaining...
# processing 15 of 292, 277 remaining...
# processing 16 of 292, 276 remaining...
# processing 17 of 292, 275 remaining...
# processing 18 of 292, 274 remaining...
# processing 19 of 292, 273 remaining...
# processing 20 of 292, 272 remaining...
# processing 21 of 292, 271 remaining...
# processing 22 of 292, 270 remaining...
# processing 23 of 292, 269 remaining...
# processing 24 of 292, 268 remaining...
# processing 25 of 292, 267 remaining...
# processing 26 of 292, 266 remaining...
# processing 27 of 292, 265 remaining...
# processing 28 of 292, 264 remaining...
# processing 29 of 292, 263 remaining...
# processing 30 of 292, 262 remaining...
# processing 31 of 292, 261 remaining...
# processing 32 of 292, 260 remaining...
# processing 33 of 292, 259 remaining...
# processing 34 of 292, 258 remaining...
# processing 35 of 292, 257 remaining...
# processing 36 of 292, 256 remaining...
# processing 37 of 292, 255 remaining...
# processing 38 of 292, 254 remaining...
# processing 39 of 292, 253 remaining...
# processing 40 of 292, 252 remaining...
# processing 41 of 292, 251 remaining...
# processing 42 of 292, 250 remaining...
# processing 43 of 292, 249 remaining...
# processing 44 of 292, 248 remaining...
# processing 45 of 292, 247 remaining...
# processing 46 of 292, 246 remaining...
# processing 47 of 292, 245 remaining...
# processing 48 of 292, 244 remaining...
# processing 49 of 292, 243 remaining...
# processing 50 of 292, 242 remaining...
# processing 51 of 292, 241 remaining...
# processing 52 of 292, 240 remaining...
# processing 53 of 292, 239 remaining...
# processing 54 of 292, 238 remaining...
# processing 55 of 292, 237 remaining...
# processing 56 of 292, 236 remaining...
# processing 57 of 292, 235 remaining...
# processing 58 of 292, 234 remaining...
# processing 59 of 292, 233 remaining...
# processing 60 of 292, 232 remaining...
# processing 61 of 292, 231 remaining...
# processing 62 of 292, 230 remaining...
# processing 63 of 292, 229 remaining...
# processing 64 of 292, 228 remaining...
# processing 65 of 292, 227 remaining...
# processing 66 of 292, 226 remaining...
# processing 67 of 292, 225 remaining...
# processing 68 of 292, 224 remaining...
# processing 69 of 292, 223 remaining...
# processing 70 of 292, 222 remaining...
# processing 71 of 292, 221 remaining...
# processing 72 of 292, 220 remaining...
# processing 73 of 292, 219 remaining...
# processing 74 of 292, 218 remaining...
# processing 75 of 292, 217 remaining...
# processing 76 of 292, 216 remaining...
# processing 77 of 292, 215 remaining...
# processing 78 of 292, 214 remaining...
# processing 79 of 292, 213 remaining...
# processing 80 of 292, 212 remaining...
# processing 81 of 292, 211 remaining...
# processing 82 of 292, 210 remaining...
# processing 83 of 292, 209 remaining...
# processing 84 of 292, 208 remaining...
# processing 85 of 292, 207 remaining...
# processing 86 of 292, 206 remaining...
# processing 87 of 292, 205 remaining...
# processing 88 of 292, 204 remaining...
# processing 89 of 292, 203 remaining...
# processing 90 of 292, 202 remaining...
# processing 91 of 292, 201 remaining...
# processing 92 of 292, 200 remaining...
# processing 93 of 292, 199 remaining...
# processing 94 of 292, 198 remaining...
# processing 95 of 292, 197 remaining...
# processing 96 of 292, 196 remaining...
# processing 97 of 292, 195 remaining...
# processing 98 of 292, 194 remaining...
# processing 99 of 292, 193 remaining...
# processing 100 of 292, 192 remaining...
# processing 101 of 292, 191 remaining...
# processing 102 of 292, 190 remaining...
# processing 103 of 292, 189 remaining...
# processing 104 of 292, 188 remaining...
# processing 105 of 292, 187 remaining...
# processing 106 of 292, 186 remaining...
# processing 107 of 292, 185 remaining...
# processing 108 of 292, 184 remaining...
# processing 109 of 292, 183 remaining...
# processing 110 of 292, 182 remaining...
# processing 111 of 292, 181 remaining...
# processing 112 of 292, 180 remaining...
# processing 113 of 292, 179 remaining...
# processing 114 of 292, 178 remaining...
# processing 115 of 292, 177 remaining...
# processing 116 of 292, 176 remaining...
# processing 117 of 292, 175 remaining...
# processing 118 of 292, 174 remaining...
# processing 119 of 292, 173 remaining...
# processing 120 of 292, 172 remaining...
# processing 121 of 292, 171 remaining...
# processing 122 of 292, 170 remaining...
# processing 123 of 292, 169 remaining...
# processing 124 of 292, 168 remaining...
# processing 125 of 292, 167 remaining...
# processing 126 of 292, 166 remaining...
# processing 127 of 292, 165 remaining...
# processing 128 of 292, 164 remaining...
# processing 129 of 292, 163 remaining...
# processing 130 of 292, 162 remaining...
# processing 131 of 292, 161 remaining...
# processing 132 of 292, 160 remaining...
# processing 133 of 292, 159 remaining...
# processing 134 of 292, 158 remaining...
# processing 135 of 292, 157 remaining...
# processing 136 of 292, 156 remaining...
# processing 137 of 292, 155 remaining...
# processing 138 of 292, 154 remaining...
# processing 139 of 292, 153 remaining...
# processing 140 of 292, 152 remaining...
# processing 141 of 292, 151 remaining...
# processing 142 of 292, 150 remaining...
# processing 143 of 292, 149 remaining...
# processing 144 of 292, 148 remaining...
# processing 145 of 292, 147 remaining...
# processing 146 of 292, 146 remaining...
# processing 147 of 292, 145 remaining...
# processing 148 of 292, 144 remaining...
# processing 149 of 292, 143 remaining...
# processing 150 of 292, 142 remaining...
# processing 151 of 292, 141 remaining...
# processing 152 of 292, 140 remaining...
# processing 153 of 292, 139 remaining...
# processing 154 of 292, 138 remaining...
# processing 155 of 292, 137 remaining...
# processing 156 of 292, 136 remaining...
# processing 157 of 292, 135 remaining...
# processing 158 of 292, 134 remaining...
# processing 159 of 292, 133 remaining...
# processing 160 of 292, 132 remaining...
# processing 161 of 292, 131 remaining...
# processing 162 of 292, 130 remaining...
# processing 163 of 292, 129 remaining...
# processing 164 of 292, 128 remaining...
# processing 165 of 292, 127 remaining...
# processing 166 of 292, 126 remaining...
# processing 167 of 292, 125 remaining...
# processing 168 of 292, 124 remaining...
# processing 169 of 292, 123 remaining...
# processing 170 of 292, 122 remaining...
# processing 171 of 292, 121 remaining...
# processing 172 of 292, 120 remaining...
# processing 173 of 292, 119 remaining...
# processing 174 of 292, 118 remaining...
# processing 175 of 292, 117 remaining...
# processing 176 of 292, 116 remaining...
# processing 177 of 292, 115 remaining...
# processing 178 of 292, 114 remaining...
# processing 179 of 292, 113 remaining...
# processing 180 of 292, 112 remaining...
# processing 181 of 292, 111 remaining...
# processing 182 of 292, 110 remaining...
# processing 183 of 292, 109 remaining...
# processing 184 of 292, 108 remaining...
# processing 185 of 292, 107 remaining...
# processing 186 of 292, 106 remaining...
# processing 187 of 292, 105 remaining...
# processing 188 of 292, 104 remaining...
# processing 189 of 292, 103 remaining...
# processing 190 of 292, 102 remaining...
# processing 191 of 292, 101 remaining...
# processing 192 of 292, 100 remaining...
# processing 193 of 292, 99 remaining...
# processing 194 of 292, 98 remaining...
# processing 195 of 292, 97 remaining...
# processing 196 of 292, 96 remaining...
# processing 197 of 292, 95 remaining...
# processing 198 of 292, 94 remaining...
# processing 199 of 292, 93 remaining...
# processing 200 of 292, 92 remaining...
# processing 201 of 292, 91 remaining...
# processing 202 of 292, 90 remaining...
# processing 203 of 292, 89 remaining...
# processing 204 of 292, 88 remaining...
# processing 205 of 292, 87 remaining...
# processing 206 of 292, 86 remaining...
# processing 207 of 292, 85 remaining...
# processing 208 of 292, 84 remaining...
# processing 209 of 292, 83 remaining...
# processing 210 of 292, 82 remaining...
# processing 211 of 292, 81 remaining...
# processing 212 of 292, 80 remaining...
# processing 213 of 292, 79 remaining...
# processing 214 of 292, 78 remaining...
# processing 215 of 292, 77 remaining...
# processing 216 of 292, 76 remaining...
# processing 217 of 292, 75 remaining...
# processing 218 of 292, 74 remaining...
# processing 219 of 292, 73 remaining...
# processing 220 of 292, 72 remaining...
# processing 221 of 292, 71 remaining...
# processing 222 of 292, 70 remaining...
# processing 223 of 292, 69 remaining...
# processing 224 of 292, 68 remaining...
# processing 225 of 292, 67 remaining...
# processing 226 of 292, 66 remaining...
# processing 227 of 292, 65 remaining...
# processing 228 of 292, 64 remaining...
# processing 229 of 292, 63 remaining...
# processing 230 of 292, 62 remaining...
# processing 231 of 292, 61 remaining...
# processing 232 of 292, 60 remaining...
# processing 233 of 292, 59 remaining...
# processing 234 of 292, 58 remaining...
# processing 235 of 292, 57 remaining...
# processing 236 of 292, 56 remaining...
# processing 237 of 292, 55 remaining...
# processing 238 of 292, 54 remaining...
# processing 239 of 292, 53 remaining...
# processing 240 of 292, 52 remaining...
# processing 241 of 292, 51 remaining...
# processing 242 of 292, 50 remaining...
# processing 243 of 292, 49 remaining...
# processing 244 of 292, 48 remaining...
# processing 245 of 292, 47 remaining...
# processing 246 of 292, 46 remaining...
# processing 247 of 292, 45 remaining...
# processing 248 of 292, 44 remaining...
# processing 249 of 292, 43 remaining...
# processing 250 of 292, 42 remaining...
# processing 251 of 292, 41 remaining...
# processing 252 of 292, 40 remaining...
# processing 253 of 292, 39 remaining...
# processing 254 of 292, 38 remaining...
# processing 255 of 292, 37 remaining...
# processing 256 of 292, 36 remaining...
# processing 257 of 292, 35 remaining...
# processing 258 of 292, 34 remaining...
# processing 259 of 292, 33 remaining...
# processing 260 of 292, 32 remaining...
# processing 261 of 292, 31 remaining...
# processing 262 of 292, 30 remaining...
# processing 263 of 292, 29 remaining...
# processing 264 of 292, 28 remaining...
# processing 265 of 292, 27 remaining...
# processing 266 of 292, 26 remaining...
# processing 267 of 292, 25 remaining...
# processing 268 of 292, 24 remaining...
# processing 269 of 292, 23 remaining...
# processing 270 of 292, 22 remaining...
# processing 271 of 292, 21 remaining...
# processing 272 of 292, 20 remaining...
# processing 273 of 292, 19 remaining...
# processing 274 of 292, 18 remaining...
# processing 275 of 292, 17 remaining...
# processing 276 of 292, 16 remaining...
# processing 277 of 292, 15 remaining...
# processing 278 of 292, 14 remaining...
# processing 279 of 292, 13 remaining...
# processing 280 of 292, 12 remaining...
# processing 281 of 292, 11 remaining...
# processing 282 of 292, 10 remaining...
# processing 283 of 292, 9 remaining...
# processing 284 of 292, 8 remaining...
# processing 285 of 292, 7 remaining...
# processing 286 of 292, 6 remaining...
# processing 287 of 292, 5 remaining...
# processing 288 of 292, 4 remaining...
# processing 289 of 292, 3 remaining...
# processing 290 of 292, 2 remaining...
# processing 291 of 292, 1 remaining...
# processing 292 of 292, 0 remaining...

# %% [markdown]
# ### Generate IncomeExpense data

# %%
try:
    munis = pd.DataFrame(list(models.Officials.objects.all().values()))
    muni_codes = [str(x).upper() for x in pd.unique(munis.demarcation_code)]
    models.IncomeExpense.objects.all().delete()
    count = 1
    for code in muni_codes:
        print("processing {0} of {1}, {2} remaining...".format(count, len(muni_codes), len(muni_codes) - count))
        incexp = pd.DataFrame(
            requests.get('https://municipaldata.treasury.gov.za/api/cubes/incexp/aggregate?drilldown=amount_type.label|financial_year_end.year|demarcation.code|demarcation.label|item.label&cut=demarcation.code:%22'+ code +'%22&aggregates=amount.sum',
                                          allow_redirects=True).json()['cells']
        )

        incexp['amount.sum'] = incexp['amount.sum'].transform(lambda x: x.fillna(0))
        for col in incexp.columns:
            incexp[col] = incexp[col].apply(lambda x: str(x).lower())

        incexp = incexp[['amount_type.label', 'financial_year_end.year', 'item.label', 'demarcation.code', 'demarcation.label', 'amount.sum']]
        incexp.rename(columns={'amount_type.label':'amount_type',  
                               'financial_year_end.year':'financial_year_end', 
                               'amount.sum':'amount',
                                'item.label':'item_label', 'demarcation.code':'demarcation_code', 'demarcation.label':'demarcation_label'}, 
                      inplace=True)
        incexp.amount = incexp.amount.transform(lambda x: float(x))
        incexp.financial_year_end = incexp.financial_year_end.transform(lambda x: int(x))

        incexp = incexp.sort_values(by=['financial_year_end', 'amount'], ascending=False)
        incexp.drop_duplicates(inplace=True)

        incexp.fillna('not availiable', inplace=True)
        incexp.groupby('financial_year_end').count()
        incexp.to_sql('app_incomeexpense', engine, if_exists='append', index=False)
        print("Row Count", models.IncomeExpense.objects.count())
        count += 1
        
except Exception as ex:
    print("ERROR:", ex)
# Out:
# processing 1 of 292, 291 remaining...
# Row Count 3015
# processing 2 of 292, 290 remaining...
# Row Count 6231
# processing 3 of 292, 289 remaining...
# Row Count 9380
# processing 4 of 292, 288 remaining...
# Row Count 12596
# processing 5 of 292, 287 remaining...
# Row Count 15410
# processing 6 of 292, 286 remaining...
# Row Count 18358
# processing 7 of 292, 285 remaining...
# Row Count 21373
# processing 8 of 292, 284 remaining...
# Row Count 23986
# processing 9 of 292, 283 remaining...
# Row Count 27202
# processing 10 of 292, 282 remaining...
# Row Count 30418
# processing 11 of 292, 281 remaining...
# Row Count 33500
# processing 12 of 292, 280 remaining...
# Row Count 36716
# processing 13 of 292, 279 remaining...
# Row Count 39798
# processing 14 of 292, 278 remaining...
# Row Count 43014
# processing 15 of 292, 277 remaining...
# Row Count 46230
# processing 16 of 292, 276 remaining...
# Row Count 49379
# processing 17 of 292, 275 remaining...
# Row Count 52528
# processing 18 of 292, 274 remaining...
# Row Count 55744
# processing 19 of 292, 273 remaining...
# Row Count 58893
# processing 20 of 292, 272 remaining...
# Row Count 62042
# processing 21 of 292, 271 remaining...
# Row Count 65258
# processing 22 of 292, 270 remaining...
# Row Count 68474
# processing 23 of 292, 269 remaining...
# Row Count 71623
# processing 24 of 292, 268 remaining...
# Row Count 74705
# processing 25 of 292, 267 remaining...
# Row Count 77921
# processing 26 of 292, 266 remaining...
# Row Count 80668
# processing 27 of 292, 265 remaining...
# Row Count 83482
# processing 28 of 292, 264 remaining...
# Row Count 86564
# processing 29 of 292, 263 remaining...
# Row Count 89713
# processing 30 of 292, 262 remaining...
# Row Count 92661
# processing 31 of 292, 261 remaining...
# Row Count 95743
# processing 32 of 292, 260 remaining...
# Row Count 98557
# processing 33 of 292, 259 remaining...
# Row Count 101304
# processing 34 of 292, 258 remaining...
# Row Count 104453
# processing 35 of 292, 257 remaining...
# Row Count 107267
# processing 36 of 292, 256 remaining...
# Row Count 110282
# processing 37 of 292, 255 remaining...
# Row Count 113431
# processing 38 of 292, 254 remaining...
# Row Count 116312
# processing 39 of 292, 253 remaining...
# Row Count 119126
# processing 40 of 292, 252 remaining...
# Row Count 121873
# processing 41 of 292, 251 remaining...
# Row Count 124955
# processing 42 of 292, 250 remaining...
# Row Count 128037
# processing 43 of 292, 249 remaining...
# Row Count 130985
# processing 44 of 292, 248 remaining...
# Row Count 133866
# processing 45 of 292, 247 remaining...
# Row Count 136948
# processing 46 of 292, 246 remaining...
# Row Count 140164
# processing 47 of 292, 245 remaining...
# Row Count 143179
# processing 48 of 292, 244 remaining...
# Row Count 146261
# processing 49 of 292, 243 remaining...
# Row Count 148606
# processing 50 of 292, 242 remaining...
# Row Count 151353
# processing 51 of 292, 241 remaining...
# Row Count 154100
# processing 52 of 292, 240 remaining...
# Row Count 156780
# processing 53 of 292, 239 remaining...
# Row Count 159192
# processing 54 of 292, 238 remaining...
# Row Count 162408
# processing 55 of 292, 237 remaining...
# Row Count 165289
# processing 56 of 292, 236 remaining...
# Row Count 168103
# processing 57 of 292, 235 remaining...
# Row Count 171252
# processing 58 of 292, 234 remaining...
# Row Count 174401
# processing 59 of 292, 233 remaining...
# Row Count 176880
# processing 60 of 292, 232 remaining...
# Row Count 179560
# processing 61 of 292, 231 remaining...
# Row Count 181771
# processing 62 of 292, 230 remaining...
# Row Count 183848
# processing 63 of 292, 229 remaining...
# Row Count 184518
# processing 64 of 292, 228 remaining...
# Row Count 187265
# processing 65 of 292, 227 remaining...
# Row Count 189543
# processing 66 of 292, 226 remaining...
# Row Count 191754
# processing 67 of 292, 225 remaining...
# Row Count 194300
# processing 68 of 292, 224 remaining...
# Row Count 196980
# processing 69 of 292, 223 remaining...
# Row Count 200129
# processing 70 of 292, 222 remaining...
# Row Count 203010
# processing 71 of 292, 221 remaining...
# Row Count 205422
# processing 72 of 292, 220 remaining...
# Row Count 205824
# processing 73 of 292, 219 remaining...
# Row Count 208839
# processing 74 of 292, 218 remaining...
# Row Count 211988
# processing 75 of 292, 217 remaining...
# Row Count 214601
# processing 76 of 292, 216 remaining...
# Row Count 216946
# processing 77 of 292, 215 remaining...
# Row Count 217616
# processing 78 of 292, 214 remaining...
# Row Count 220363
# processing 79 of 292, 213 remaining...
# Row Count 222909
# processing 80 of 292, 212 remaining...
# Row Count 225991
# processing 81 of 292, 211 remaining...
# Row Count 228805
# processing 82 of 292, 210 remaining...
# Row Count 231887
# processing 83 of 292, 209 remaining...
# Row Count 234969
# processing 84 of 292, 208 remaining...
# Row Count 237783
# processing 85 of 292, 207 remaining...
# Row Count 240530
# processing 86 of 292, 206 remaining...
# Row Count 243210
# processing 87 of 292, 205 remaining...
# Row Count 246292
# processing 88 of 292, 204 remaining...
# Row Count 249307
# processing 89 of 292, 203 remaining...
# Row Count 252523
# processing 90 of 292, 202 remaining...
# Row Count 255337
# processing 91 of 292, 201 remaining...
# Row Count 258486
# processing 92 of 292, 200 remaining...
# Row Count 260362
# processing 93 of 292, 199 remaining...
# Row Count 263243
# processing 94 of 292, 198 remaining...
# Row Count 266124
# processing 95 of 292, 197 remaining...
# Row Count 269273
# processing 96 of 292, 196 remaining...
# Row Count 272422
# processing 97 of 292, 195 remaining...
# Row Count 275303
# processing 98 of 292, 194 remaining...
# Row Count 278251
# processing 99 of 292, 193 remaining...
# Row Count 281132
# processing 100 of 292, 192 remaining...
# Row Count 284013
# processing 101 of 292, 191 remaining...
# Row Count 287095
# processing 102 of 292, 190 remaining...
# Row Count 289909
# processing 103 of 292, 189 remaining...
# Row Count 292723
# processing 104 of 292, 188 remaining...
# Row Count 295470
# processing 105 of 292, 187 remaining...
# Row Count 298351
# processing 106 of 292, 186 remaining...
# Row Count 301567
# processing 107 of 292, 185 remaining...
# Row Count 304582
# processing 108 of 292, 184 remaining...
# Row Count 307664
# processing 109 of 292, 183 remaining...
# Row Count 310679
# processing 110 of 292, 182 remaining...
# Row Count 313828
# processing 111 of 292, 181 remaining...
# Row Count 317044
# processing 112 of 292, 180 remaining...
# Row Count 319456
# processing 113 of 292, 179 remaining...
# Row Count 321734
# processing 114 of 292, 178 remaining...
# Row Count 324548
# processing 115 of 292, 177 remaining...
# Row Count 325218
# processing 116 of 292, 176 remaining...
# Row Count 328300
# processing 117 of 292, 175 remaining...
# Row Count 330578
# processing 118 of 292, 174 remaining...
# Row Count 333727
# processing 119 of 292, 173 remaining...
# Row Count 336943
# processing 120 of 292, 172 remaining...
# Row Count 340025
# processing 121 of 292, 171 remaining...
# Row Count 342504
# processing 122 of 292, 170 remaining...
# Row Count 345385
# processing 123 of 292, 169 remaining...
# Row Count 348467
# processing 124 of 292, 168 remaining...
# Row Count 351683
# processing 125 of 292, 167 remaining...
# Row Count 354899
# processing 126 of 292, 166 remaining...
# Row Count 357847
# processing 127 of 292, 165 remaining...
# Row Count 360795
# processing 128 of 292, 164 remaining...
# Row Count 363944
# processing 129 of 292, 163 remaining...
# Row Count 367160
# processing 130 of 292, 162 remaining...
# Row Count 369773
# processing 131 of 292, 161 remaining...
# Row Count 372118
# processing 132 of 292, 160 remaining...
# Row Count 374664
# processing 133 of 292, 159 remaining...
# Row Count 377880
# processing 134 of 292, 158 remaining...
# Row Count 380493
# processing 135 of 292, 157 remaining...
# Row Count 381096
# processing 136 of 292, 156 remaining...
# Row Count 381766
# processing 137 of 292, 155 remaining...
# Row Count 384915
# processing 138 of 292, 154 remaining...
# Row Count 387997
# processing 139 of 292, 153 remaining...
# Row Count 390945
# processing 140 of 292, 152 remaining...
# Row Count 394025
# processing 141 of 292, 151 remaining...
# Row Count 397107
# processing 142 of 292, 150 remaining...
# Row Count 400189
# processing 143 of 292, 149 remaining...
# Row Count 403338
# processing 144 of 292, 148 remaining...
# Row Count 406487
# processing 145 of 292, 147 remaining...
# Row Count 409569
# processing 146 of 292, 146 remaining...
# Row Count 412718
# processing 147 of 292, 145 remaining...
# Row Count 415867
# processing 148 of 292, 144 remaining...
# Row Count 418882
# processing 149 of 292, 143 remaining...
# Row Count 421964
# processing 150 of 292, 142 remaining...
# Row Count 425046
# processing 151 of 292, 141 remaining...
# Row Count 427391
# processing 152 of 292, 140 remaining...
# Row Count 429736
# processing 153 of 292, 139 remaining...
# Row Count 432684
# processing 154 of 292, 138 remaining...
# Row Count 433287
# processing 155 of 292, 137 remaining...
# Row Count 436503
# processing 156 of 292, 136 remaining...
# Row Count 439518
# processing 157 of 292, 135 remaining...
# Row Count 441863
# processing 158 of 292, 134 remaining...
# Row Count 445012
# processing 159 of 292, 133 remaining...
# Row Count 448228
# processing 160 of 292, 132 remaining...
# Row Count 451444
# processing 161 of 292, 131 remaining...
# Row Count 454660
# processing 162 of 292, 130 remaining...
# Row Count 457876
# processing 163 of 292, 129 remaining...
# Row Count 461025
# processing 164 of 292, 128 remaining...
# Row Count 464174
# processing 165 of 292, 127 remaining...
# Row Count 466720
# processing 166 of 292, 126 remaining...
# Row Count 469266
# processing 167 of 292, 125 remaining...
# Row Count 472482
# processing 168 of 292, 124 remaining...
# Row Count 475564
# processing 169 of 292, 123 remaining...
# Row Count 478713
# processing 170 of 292, 122 remaining...
# Row Count 479383
# processing 171 of 292, 121 remaining...
# Row Count 482398
# processing 172 of 292, 120 remaining...
# Row Count 485413
# processing 173 of 292, 119 remaining...
# Row Count 488361
# processing 174 of 292, 118 remaining...
# Row Count 491309
# processing 175 of 292, 117 remaining...
# Row Count 494257
# processing 176 of 292, 116 remaining...
# Row Count 497071
# processing 177 of 292, 115 remaining...
# Row Count 499148
# processing 178 of 292, 114 remaining...
# Row Count 502029
# processing 179 of 292, 113 remaining...
# Row Count 504709
# processing 180 of 292, 112 remaining...
# Row Count 505312
# processing 181 of 292, 111 remaining...
# Row Count 508260
# processing 182 of 292, 110 remaining...
# Row Count 510471
# processing 183 of 292, 109 remaining...
# Row Count 513419
# processing 184 of 292, 108 remaining...
# Row Count 516367
# processing 185 of 292, 107 remaining...
# Row Count 519248
# processing 186 of 292, 106 remaining...
# Row Count 522129
# processing 187 of 292, 105 remaining...
# Row Count 525010
# processing 188 of 292, 104 remaining...
# Row Count 527489
# processing 189 of 292, 103 remaining...
# Row Count 530035
# processing 190 of 292, 102 remaining...
# Row Count 532648
# processing 191 of 292, 101 remaining...
# Row Count 535462
# processing 192 of 292, 100 remaining...
# Row Count 536065
# processing 193 of 292, 99 remaining...
# Row Count 538879
# processing 194 of 292, 98 remaining...
# Row Count 541894
# processing 195 of 292, 97 remaining...
# Row Count 544641
# processing 196 of 292, 96 remaining...
# Row Count 547187
# processing 197 of 292, 95 remaining...
# Row Count 548996
# processing 198 of 292, 94 remaining...
# Row Count 549599
# processing 199 of 292, 93 remaining...
# Row Count 552547
# processing 200 of 292, 92 remaining...
# Row Count 555495
# processing 201 of 292, 91 remaining...
# Row Count 558309
# processing 202 of 292, 90 remaining...
# Row Count 561391
# processing 203 of 292, 89 remaining...
# Row Count 564205
# processing 204 of 292, 88 remaining...
# Row Count 566952
# processing 205 of 292, 87 remaining...
# Row Count 569632
# processing 206 of 292, 86 remaining...
# Row Count 572580
# processing 207 of 292, 85 remaining...
# Row Count 575327
# processing 208 of 292, 84 remaining...
# Row Count 578208
# processing 209 of 292, 83 remaining...
# Row Count 581223
# processing 210 of 292, 82 remaining...
# Row Count 584171
# processing 211 of 292, 81 remaining...
# Row Count 587119
# processing 212 of 292, 80 remaining...
# Row Count 590268
# processing 213 of 292, 79 remaining...
# Row Count 593283
# processing 214 of 292, 78 remaining...
# Row Count 595762
# processing 215 of 292, 77 remaining...
# Row Count 598040
# processing 216 of 292, 76 remaining...
# Row Count 600787
# processing 217 of 292, 75 remaining...
# Row Count 603735
# processing 218 of 292, 74 remaining...
# Row Count 604405
# processing 219 of 292, 73 remaining...
# Row Count 607420
# processing 220 of 292, 72 remaining...
# Row Count 610435
# processing 221 of 292, 71 remaining...
# Row Count 613450
# processing 222 of 292, 70 remaining...
# Row Count 616465
# processing 223 of 292, 69 remaining...
# Row Count 619346
# processing 224 of 292, 68 remaining...
# Row Count 622495
# processing 225 of 292, 67 remaining...
# Row Count 625242
# processing 226 of 292, 66 remaining...
# Row Count 628257
# processing 227 of 292, 65 remaining...
# Row Count 631272
# processing 228 of 292, 64 remaining...
# Row Count 633952
# processing 229 of 292, 63 remaining...
# Row Count 636431
# processing 230 of 292, 62 remaining...
# Row Count 639178
# processing 231 of 292, 61 remaining...
# Row Count 641657
# processing 232 of 292, 60 remaining...
# Row Count 644672
# processing 233 of 292, 59 remaining...
# Row Count 647084
# processing 234 of 292, 58 remaining...
# Row Count 649965
# processing 235 of 292, 57 remaining...
# Row Count 652511
# processing 236 of 292, 56 remaining...
# Row Count 655258
# processing 237 of 292, 55 remaining...
# Row Count 658072
# processing 238 of 292, 54 remaining...
# Row Count 661020
# processing 239 of 292, 53 remaining...
# Row Count 661690
# processing 240 of 292, 52 remaining...
# Row Count 664906
# processing 241 of 292, 51 remaining...
# Row Count 667452
# processing 242 of 292, 50 remaining...
# Row Count 670266
# processing 243 of 292, 49 remaining...
# Row Count 673147
# processing 244 of 292, 48 remaining...
# Row Count 676162
# processing 245 of 292, 47 remaining...
# Row Count 679244
# processing 246 of 292, 46 remaining...
# Row Count 682192
# processing 247 of 292, 45 remaining...
# Row Count 685339
# processing 248 of 292, 44 remaining...
# Row Count 688354
# processing 249 of 292, 43 remaining...
# Row Count 691369
# processing 250 of 292, 42 remaining...
# Row Count 694116
# processing 251 of 292, 41 remaining...
# Row Count 696997
# processing 252 of 292, 40 remaining...
# Row Count 700012
# processing 253 of 292, 39 remaining...
# Row Count 702759
# processing 254 of 292, 38 remaining...
# Row Count 705372
# processing 255 of 292, 37 remaining...
# Row Count 708186
# processing 256 of 292, 36 remaining...
# Row Count 710732
# processing 257 of 292, 35 remaining...
# Row Count 713479
# processing 258 of 292, 34 remaining...
# Row Count 716494
# processing 259 of 292, 33 remaining...
# Row Count 719107
# processing 260 of 292, 32 remaining...
# Row Count 721988
# processing 261 of 292, 31 remaining...
# Row Count 725003
# processing 262 of 292, 30 remaining...
# Row Count 727281
# processing 263 of 292, 29 remaining...
# Row Count 729559
# processing 264 of 292, 28 remaining...
# Row Count 732038
# processing 265 of 292, 27 remaining...
# Row Count 735254
# processing 266 of 292, 26 remaining...
# Row Count 737934
# processing 267 of 292, 25 remaining...
# Row Count 738336
# processing 268 of 292, 24 remaining...
# Row Count 741485
# processing 269 of 292, 23 remaining...
# Row Count 744634
# processing 270 of 292, 22 remaining...
# Row Count 747783
# processing 271 of 292, 21 remaining...
# Row Count 750999
# processing 272 of 292, 20 remaining...
# Row Count 754081
# processing 273 of 292, 19 remaining...
# Row Count 757163
# processing 274 of 292, 18 remaining...
# Row Count 760245
# processing 275 of 292, 17 remaining...
# Row Count 763260
# processing 276 of 292, 16 remaining...
# Row Count 766208
# processing 277 of 292, 15 remaining...
# Row Count 769424
# processing 278 of 292, 14 remaining...
# Row Count 772573
# processing 279 of 292, 13 remaining...
# Row Count 775722
# processing 280 of 292, 12 remaining...
# Row Count 778871
# processing 281 of 292, 11 remaining...
# Row Count 781819
# processing 282 of 292, 10 remaining...
# Row Count 784834
# processing 283 of 292, 9 remaining...
# Row Count 787581
# processing 284 of 292, 8 remaining...
# Row Count 790797
# processing 285 of 292, 7 remaining...
# Row Count 793812
# processing 286 of 292, 6 remaining...
# Row Count 797028
# processing 287 of 292, 5 remaining...
# Row Count 799976
# processing 288 of 292, 4 remaining...
# Row Count 802857
# processing 289 of 292, 3 remaining...
# Row Count 805939
# processing 290 of 292, 2 remaining...
# Row Count 808954
# processing 291 of 292, 1 remaining...
# Row Count 811835
# processing 292 of 292, 0 remaining...
# Row Count 814917

# %% [markdown]
# ### Generate Munis data

# %%
munis = pd.DataFrame(requests.get('https://municipaldata.treasury.gov.za/api/cubes/municipalities/facts',
                                      allow_redirects=True).json()['data'])

munis = munis[['area', 'municipality.category', 'municipality.demarcation_code', 
                    'municipality.fax_number', 'municipality.name', 'municipality.phone_number', 'municipality.postal_address_1',
                    'municipality.postal_address_2', 'municipality.postal_address_3', 'municipality.province_name',
                    'municipality.street_address_1', 'municipality.street_address_2', 'municipality.street_address_3', 'municipality.url']]

munis.rename(columns={'area':'area', 'municipality.category':'category', 'municipality.demarcation_code':'demarcation_code', 
                    'municipality.fax_number':'fax_number', 'municipality.name':'name', 'municipality.phone_number':'phone_number', 
                      'municipality.postal_address_1':'postal_address_1','municipality.postal_address_2':'postal_address_2', 
                      'municipality.postal_address_3':'postal_code', 'municipality.province_name':'province_name',
                    'municipality.street_address_1':'street_address_1', 'municipality.street_address_2':'street_address_2', 
                      'municipality.street_address_3':'street_address_3', 'municipality.url':'website'}, inplace=True)

munis.fillna('not availiable', inplace=True)
for col in munis.columns:
    munis[col] = munis[col].apply(lambda x: str(x).lower())

models.Municipalities.objects.all().delete()

for muni in munis.values:
    dermancation_code = muni[2]
    officials = models.Officials.objects.filter( demarcation_code=dermancation_code)
    audits = models.Audits.objects.filter( demarcation_code=dermancation_code)
    balance_sheets = models.BalanceSheet.objects.filter( demarcation_code=dermancation_code)
    maintenance = models.Maintenance.objects.filter( demarcation_code=dermancation_code)
    cash_flow = models.CashFlow.objects.filter( demarcation_code=dermancation_code)
    capital = models.Capital.objects.filter( demarcation_code=dermancation_code)
    income_expense = models.IncomeExpense.objects.filter( demarcation_code=dermancation_code)
    forecast = models.Forecast.objects.filter( demarcation_code=dermancation_code)
    waste = models.WastefulExpenditure.objects.filter( demarcation_code=dermancation_code)
    
    muni = models.Municipalities.objects.create(
        area=muni[0],
        category=muni[1],
        demarcation_code=muni[2],
        fax_number=muni[3],
        name=muni[4],
        phone_number=muni[5],
        postal_address_1=muni[6],
        postal_address_2=muni[7],
        postal_code=muni[8],
        province_name=muni[9],
        street_address_1=muni[10],
        street_address_2=muni[11],
        street_address_3=muni[12],
        website=muni[13]
    )
    muni.officials.set(officials)
    muni.audits.set(audits)
    muni.balance_sheets.set(balance_sheets)
    muni.maintenance.set(maintenance)
    muni.cash_flows.set(cash_flow)
    muni.capital.set(capital)
    muni.income_expense.set(income_expense)
    muni.forecasts.set(forecast)
    muni.wasteful.set(waste)
    muni.save()

models.Municipalities.objects.count()
# Out:
# ----------------------------------------------------------------
# OperationalError               Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      84             else:
# ---> 85                 return self.cursor.execute(sql, params)
#      86
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     302         query = self.convert_query(query)
# --> 303         return Database.Cursor.execute(self, query, params)
#     304
#
# OperationalError: too many SQL variables
#
# The above exception was the direct cause of the following exception:
#
# OperationalError               Traceback (most recent call last)
# <ipython-input-14-ad0575436fca> in <module>()
#      50     muni.officials.set(officials)
#      51     muni.audits.set(audits)
# ---> 52     muni.balance_sheets.set(balance_sheets)
#      53     muni.maintenance.set(maintenance)
#      54     muni.cash_flows.set(cash_flow)
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/models/fields/related_descriptors.py in set(self, objs, clear)
#     967
#     968                     self.remove(*old_ids)
# --> 969                     self.add(*new_objs)
#     970         set.alters_data = True
#     971
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/models/fields/related_descriptors.py in add(self, *objs)
#     896             db = router.db_for_write(self.through, instance=self.instance)
#     897             with transaction.atomic(using=db, savepoint=False):
# --> 898                 self._add_items(self.source_field_name, self.target_field_name, *objs)
#     899
#     900                 # If this is a symmetrical m2m relation to self, add the mirror entry in the m2m table
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/models/fields/related_descriptors.py in _add_items(self, source_field_name, target_field_name, *objs)
#    1045                             '%s__in' % target_field_name: new_ids,
#    1046                         }))
# -> 1047                 new_ids.difference_update(vals)
#    1048
#    1049                 with transaction.atomic(using=db, savepoint=False):
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/models/query.py in __iter__(self)
#     270                - Responsible for turning the rows into model objects.
#     271         """
# --> 272         self._fetch_all()
#     273         return iter(self._result_cache)
#     274
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/models/query.py in _fetch_all(self)
#    1177     def _fetch_all(self):
#    1178         if self._result_cache is None:
# -> 1179             self._result_cache = list(self._iterable_class(self))
#    1180         if self._prefetch_related_lookups and not self._prefetch_done:
#    1181             self._prefetch_related_objects()
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/models/query.py in __iter__(self)
#     177         queryset = self.queryset
#     178         compiler = queryset.query.get_compiler(queryset.db)
# --> 179         return chain.from_iterable(compiler.results_iter(chunked_fetch=self.chunked_fetch, chunk_size=self.chunk_size))
#     180
#     181
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/models/sql/compiler.py in results_iter(self, results, tuple_expected, chunked_fetch, chunk_size)
#    1012         """Return an iterator over the results from executing this query."""
#    1013         if results is None:
# -> 1014             results = self.execute_sql(MULTI, chunked_fetch=chunked_fetch, chunk_size=chunk_size)
#    1015         fields = [s[0] for s in self.select[0:self.col_count]]
#    1016         converters = self.get_converters(fields)
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/models/sql/compiler.py in execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1061             cursor = self.connection.cursor()
#    1062         try:
# -> 1063             cursor.execute(sql, params)
#    1064         except Exception:
#    1065             # Might fail for server-side cursors (e.g. connection closed)
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      98         start = time()
#      99         try:
# --> 100             return super().execute(sql, params)
#     101         finally:
#     102             stop = time()
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      66
#      67     def execute(self, sql, params=None):
# ---> 68         return self._execute_with_wrappers(sql, params, many=False, executor=self._execute)
#      69
#      70     def executemany(self, sql, param_list):
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/backends/utils.py in _execute_with_wrappers(self, sql, params, many, executor)
#      75         for wrapper in reversed(self.db.execute_wrappers):
#      76             executor = functools.partial(wrapper, executor)
# ---> 77         return executor(sql, params, many, context)
#      78
#      79     def _execute(self, sql, params, *ignored_wrapper_args):
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83                 return self.cursor.execute(sql)
#      84             else:
# ---> 85                 return self.cursor.execute(sql, params)
#      86
#      87     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      87                 if dj_exc_type not in (DataError, IntegrityError):
#      88                     self.wrapper.errors_occurred = True
# ---> 89                 raise dj_exc_value.with_traceback(traceback) from exc_value
#      90
#      91     def __call__(self, func):
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/backends/utils.py in _execute(self, sql, params, *ignored_wrapper_args)
#      83                 return self.cursor.execute(sql)
#      84             else:
# ---> 85                 return self.cursor.execute(sql, params)
#      86
#      87     def _executemany(self, sql, param_list, *ignored_wrapper_args):
#
# ~/anaconda3/lib/python3.6/site-packages/django/db/backends/sqlite3/base.py in execute(self, query, params)
#     301             return Database.Cursor.execute(self, query)
#     302         query = self.convert_query(query)
# --> 303         return Database.Cursor.execute(self, query, params)
#     304
#     305     def executemany(self, query, param_list):
#
# OperationalError: too many SQL variables
