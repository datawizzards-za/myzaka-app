# %%
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "myzaka.settings")
import django
django.setup()
# Out:
# /Users/mabu/anaconda2/envs/ntbhack/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
from app import models
import pandas as pd

# %%
munis = pd.DataFrame(list(models.Municipalities.objects.all().values()))

# %%
munis
# Out:
#         area category demarcation_code      fax_number                 name  \
# 0     781026        A              BUF    043 743 8568         Buffalo City
# 1    3740031        A              CPT  Not Availiable    City of Cape Town
# 2     391766        C              DC1    086 692 6113           West Coast
# 3     450585        C             DC10    041 508 7022               Cacadu
# 4     855793        C             DC12    043 742 0337             Amathole
# 5     806478        C             DC13    045 839 2355           Chris Hani
# 6     348667        C             DC14    045 979 3028            Joe Gqabi
# 7    1366044        C             DC15    047 532 4166            O.R.Tambo
# 8     121945        C             DC16    051 713 0461              Xhariep
# 9     624746        C             DC18    057 357 4103        Lejweleputswa
# 10    735680        C             DC19    058 713 0940   Thabo Mofutsanyane
# ...

# %%
munis.groupby('category').count()

# %%
officials = models.Officials.objects.all()

# %%
officials = pd.DataFrame(list(officials.values()))

# %%
officials.head(3)

# %%
officials.groupby('email_address').count()

# %%
officials.loc[officials['email_address']=='Bonolo.rauwane@gmail.com']

# %%
officials.groupby(['demarcation_code', 'role']).count()

# %%
df = officials.groupby(['demarcation_code', 'role']).count().unstack().email_address

# %%
df.head(2)

# %%
max(list(df['Chief Financial Officer']))
